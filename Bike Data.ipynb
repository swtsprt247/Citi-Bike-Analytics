# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

# %%
file_name1 = os.path.join("1st quarter 2017.csv" )
file_name2 = os.path.join("2nd quarter 2017.csv" )
file_name3 = os.path.join("3rd quarter 2017.csv" )
file_name4 = os.path.join("4th quarter 2017.csv" )

firstQ = pd.read_csv(file_name1)
secondQ = pd.read_csv(file_name2)
thirdQ = pd.read_csv(file_name3)
fourthQ = pd.read_csv(file_name4)

# %%
firstQ.head()
# Out:
#        Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  1/1/2017                                              16009
# 1  1/2/2017                                               8921
# 2  1/3/2017                                              14198
# 3  1/4/2017                                              34039
# 4  1/5/2017                                              28393
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        50761
# 1                                        21545
# 2                                        25879
# 3                                        69966
# 4                                        52446
#
#    Total Annual Members (All Time)  \
# 0                           206624
# 1                           206675
# 2                           206728
# 3                           206778
# 4                           206845
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
secondQ.head()
# Out:
#        Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  4/1/2017                                              23849
# 1  4/2/2017                                              39779
# 2  4/3/2017                                              43484
# 3  4/4/2017                                              29990
# 4  4/5/2017                                              47635
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        67299
# 1                                       130087
# 2                                       104217
# 3                                        63091
# 4                                       108281
#
#    Total Annual Members (All Time)  \
# 0                           210739
# 1                           210915
# 2                           211075
# 3                           211171
# 4                           211310
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
#merge tabels
frames = [firstQ, secondQ, thirdQ, fourthQ]

# %%
result = pd.concat(frames)

# %%
result
# Out:
#           Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0     1/1/2017                                              16009
# 1     1/2/2017                                               8921
# 2     1/3/2017                                              14198
# 3     1/4/2017                                              34039
# 4     1/5/2017                                              28393
# 5     1/6/2017                                              24177
# 6     1/7/2017                                               4425
# 7     1/8/2017                                               6417
# 8     1/9/2017                                              15856
# 9    1/10/2017                                              23232
# 10   1/11/2017                                              32419
# 11   1/12/2017                                              39783
# 12   1/13/2017                                              33611
# ...

# %%
result.to_csv("All Quarters 2017.csv")

# %%
 file_name20 = os.path.join("All Quarters 2017.csv" )
all_quarters = pd.read_csv(file_name20)

# %%
all_quarters.head()
# Out:
#    Unnamed: 0      Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0           0  1/1/2017                                              16009
# 1           1  1/2/2017                                               8921
# 2           2  1/3/2017                                              14198
# 3           3  1/4/2017                                              34039
# 4           4  1/5/2017                                              28393
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        50761
# 1                                        21545
# 2                                        25879
# 3                                        69966
# 4                                        52446
#
#    Total Annual Members (All Time)  \
# 0                           206624
# 1                           206675
# 2                           206728
# 3                           206778
# 4                           206845
#
# ...

# %%
file_name5 = os.path.join("JC-201701-citibike-tripdata.csv" )
file_name6 = os.path.join("JC-201702-citibike-tripdata.csv" )
file_name7 = os.path.join("JC-201703-citibike-tripdata.csv" )
file_name8 = os.path.join("JC-201704-citibike-tripdata.csv" )
file_name9 = os.path.join("JC-201705-citibike-tripdata.csv" )
file_name10 = os.path.join("JC-201706-citibike-tripdata.csv" )
file_name11 = os.path.join("JC-201707-citibike-tripdata.csv" )
file_name12 = os.path.join("JC-201708 citibike-tripdata.csv" )
file_name13 = os.path.join("JC-201709-citibike-tripdata.csv" )
file_name14 = os.path.join("JC-201710-citibike-tripdata.csv" )
file_name15 = os.path.join("JC-201711-citibike-tripdata.csv" )
file_name16 = os.path.join("JC-201712-citibike-tripdata.csv" )

january_trip_data = pd.read_csv(file_name5)
february_trip_data = pd.read_csv(file_name6)
march_trip_data = pd.read_csv(file_name7)
april_trip_data = pd.read_csv(file_name8)
may_trip_data = pd.read_csv(file_name9)
june_trip_data = pd.read_csv(file_name10)
july_trip_data = pd.read_csv(file_name11)
august_trip_data = pd.read_csv(file_name12)
september_trip_data = pd.read_csv(file_name13)
october_trip_data = pd.read_csv(file_name14)
november_trip_data = pd.read_csv(file_name15)
december_trip_data = pd.read_csv(file_name16)

# %%
january_trip_data.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            148  2017-01-01 00:21:32  2017-01-01 00:24:01              3276
# 1           1283  2017-01-01 00:24:35  2017-01-01 00:45:58              3183
# 2            372  2017-01-01 00:38:19  2017-01-01 00:44:31              3183
# 3           1513  2017-01-01 00:38:37  2017-01-01 01:03:50              3194
# 4            639  2017-01-01 01:47:52  2017-01-01 01:58:31              3183
#
#   Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0   Marin Light Rail               40.714584               -74.042817
# 1     Exchange Place               40.716247               -74.033459
# 2     Exchange Place               40.716247               -74.033459
# 3    McGinley Square               40.725340               -74.067622
# 4     Exchange Place               40.716247               -74.033459
#
#    End Station ID     End Station Name  End Station Latitude  \
# ...

# %%
#merge tabels
framesII = [january_trip_data, february_trip_data, march_trip_data, april_trip_data,
           may_trip_data, june_trip_data, july_trip_data, august_trip_data,
           september_trip_data, october_trip_data, november_trip_data, december_trip_data]

# %%
resultII = pd.concat(framesII)

# %%
resultII.to_csv("Trip History 2017.csv")

# %%
 file_name17 = os.path.join("Trip History 2017.csv" )
 trip_history = pd.read_csv(file_name17)

# %%
trip_history
# Out:
#         Unnamed: 0  Bike ID  Birth Year  End Station ID  End Station Latitude  \
# 0                0    24575      1983.0            3185             40.717733
# 1                1    24723      1978.0            3198             40.748716
# 2                2    24620      1989.0            3211             40.721525
# 3                3    24668      1961.0            3271             40.692640
# 4                4    26167      1993.0            3203             40.727596
# 5                5    24604      1970.0            3270             40.725289
# 6                6    24641      1978.0            3206             40.731169
# 7                7    24513      1970.0            3213             40.718489
# 8                8    24463      1967.0            3213             40.718489
# 9                9    24486      1984.0            3225             40.723659
# 10              10    24520      1987.0            3225             40.723659
# ...

# %%
trip_history.count()
# Out:
# Unnamed: 0                 294928
# Bike ID                    294928
# Birth Year                 275313
# End Station ID             294928
# End Station Latitude       294928
# End Station Longitude      294928
# End Station Name           294928
# Gender                     294928
# Start Station ID           294928
# Start Station Latitude     294928
# Start Station Longitude    294928
# Start Station Name         294928
# Start Time                 294928
# Stop Time                  294928
# Trip Duration              294928
# User Type                  294811
# dtype: int64
